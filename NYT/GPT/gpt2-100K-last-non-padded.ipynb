# %% [markdown]
# # Definitions (run first!)

# %%
# !pip install wandb
# !wandb login
# Out:
# Collecting wandb
#   Downloading wandb-0.10.30-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 1.6 MB/s
# Collecting sentry-sdk>=0.4.0
#   Downloading sentry_sdk-1.1.0-py2.py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 10.7 MB/s
# Collecting subprocess32>=3.5.3
#   Using cached subprocess32-3.5.4-py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/mbaliesnyi/anaconda3/envs/nlp/lib/python3.8/site-packages (from wandb) (2.8.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/mbaliesnyi/anaconda3/envs/nlp/lib/python3.8/site-packages (from wandb) (2.25.1)
# Requirement already satisfied: protobuf>=3.12.0 in /home/mbaliesnyi/anaconda3/envs/nlp/lib/python3.8/site-packages (from wandb) (3.15.8)
# Requirement already satisfied: Click>=7.0 in /home/mbaliesnyi/anaconda3/envs/nlp/lib/python3.8/site-packages (from wandb) (7.1.2)
# Requirement already satisfied: six>=1.13.0 in /home/mbaliesnyi/anaconda3/envs/nlp/lib/python3.8/site-packages (from wandb) (1.15.0)
# Collecting PyYAML
#   Using cached PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
# Collecting shortuuid>=0.5.0
#   Using cached shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.14-py3-none-any.whl (159 kB)
#      |████████████████████████████████| 159 kB 10.1 MB/s
# Collecting configparser>=3.8.1
#   Downloading configparser-5.0.2-py3-none-any.whl (19 kB)
# Collecting promise<3,>=2.0
#   Using cached promise-2.3-py3-none-any.whl
# Collecting psutil>=5.0.0
#   Using cached psutil-5.8.0-cp38-cp38-manylinux2010_x86_64.whl (296 kB)
# Collecting pathtools
#   Using cached pathtools-0.1.2-py3-none-any.whl
# Collecting docker-pycreds>=0.4.0
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 4.7 MB/s
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/mbaliesnyi/anaconda3/envs/nlp/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mbaliesnyi/anaconda3/envs/nlp/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/mbaliesnyi/anaconda3/envs/nlp/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/mbaliesnyi/anaconda3/envs/nlp/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (4.0.0)
# Installing collected packages: smmap, gitdb, subprocess32, shortuuid, sentry-sdk, PyYAML, psutil, promise, pathtools, GitPython, docker-pycreds, configparser, wandb
# Successfully installed GitPython-3.1.14 PyYAML-5.4.1 configparser-5.0.2 docker-pycreds-0.4.0 gitdb-4.0.7 pathtools-0.1.2 promise-2.3 psutil-5.8.0 sentry-sdk-1.1.0 shortuuid-1.0.1 smmap-4.0.0 subprocess32-3.5.4 wandb-0.10.30
# wandb: Currently logged in as: ut-mit-news-classify (use `wandb login --relogin` to force relogin)

# %%
import gzip
import pickle
import random
import requests
import csv
from torch.utils.data import Dataset, DataLoader, random_split
from mitnewsclassify.gpt_model import GPTModel as GPTHead
from transformers import GPT2Tokenizer, GPT2Model
import torch
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np
import wandb

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
seed = 42

# %%
class GPTEmbeddedDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx], idx

# %%
import csv

def loadcsv(filename):
    with open(filename, newline='', encoding='utf-8') as f:
        return list(csv.reader(f))

def load_label_map(out2id_path, id2label_path):
    
    out2id = loadcsv(out2id_path)
    out2id = {int(row[0]): row[1] for row in out2id}

    id2label_raw = loadcsv(id2label_path)
    id2label = {}

    for row in id2label_raw:
        if row == []:
            continue
        id2label[row[1]] = row[2]

    out2label = [id2label[out2id[out]] for out in sorted(out2id.keys())]
    
    return out2label

out2label = load_label_map('labels_dict_gpt.csv', 'nyt-theme-tags.csv')
mlb = MultiLabelBinarizer(classes=out2label)
mlb.fit(out2label)
# Out:
# MultiLabelBinarizer(classes=['suspensions, dismissals and resignations',
#                              'education and schools',
#                              'colleges and universities', 'blacks',
#                              'population', 'economic conditions and trends',
#                              'labor',
#                              'office buildings and commercial properties',
#                              'architecture', 'medicine and health',
#                              'awards, decorations and honors',
#                              'diseases and conditions', 'research', 'cancer',
#                              'basketball', 'design', 'interior design',
#                              'real estate', 'trades (sports)',
#                              'demonstrations and riots', 'dancing',
#                              'hockey, ice', 'games', 'playoff games',
#                              'baseball', 'travel and vacations', 'finances',
#                              'books and literature',
#                              'united states politics and government',
#                              'politics and government', ...])

# %%
# temporary dataset for storing tokenized articles & transformed labels
class NYTDataset(Dataset):
    def __init__(self, articles, labels):

        self.tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
        self.tokenizer.pad_token = self.tokenizer.eos_token

        print('Tokenizing...')
        self.articles = self.tokenizer(articles, add_special_tokens=True, padding="max_length", truncation=True,
                                       max_length=1024, return_tensors="pt", return_attention_mask=True)

        self.input_ids = self.articles['input_ids']
        self.attention_mask = self.articles['attention_mask']

        print('Preprocessing labels...')
        self.labels = mlb.transform(labels)
        print('Done')

    def __len__(self):
        return len(self.articles)

    def __getitem__(self, idx):
        # return self.articles[idx], self.labels[idx]
        return self.input_ids[idx], self.attention_mask[idx], self.labels[idx]

# %%
import time
import math

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

def validation_split(dataset, validation_subset, seed=42):

    if validation_subset > 0:
        n_total_samples = len(dataset)
        n_train_samples = math.floor(n_total_samples * (1-validation_subset))
        n_valid_samples = n_total_samples - n_train_samples

        train_subset, valid_subset = random_split(
            dataset,
            [n_train_samples, n_valid_samples],
            generator=torch.Generator().manual_seed(seed)
        )  # reproducible results

    else:
        train_subset = dataset
        valid_subset = None

    return train_subset, valid_subset

# %%
def train(model, iterator, optimizer, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    epoch_precision = 0
    epoch_recall = 0
    epoch_f_score = 0
    
    model.train()
    

    for i, batch in enumerate(iterator):

        article_embeddings, labels, idx  = batch
        article_embeddings = article_embeddings.to(device)
        labels = labels.type(torch.float).to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(article_embeddings)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # calculate metrics
        preds = model.act(outputs) > 0.5

        acc, precision, recall, f1 = multi_label_scores(labels.detach().cpu(), preds.detach().cpu())
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        epoch_precision += precision.item()
        epoch_recall += recall.item()
        epoch_f_score += f1.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator), \
        epoch_precision / len(iterator), epoch_recall / len(iterator), \
        epoch_f_score / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    epoch_precision = 0
    epoch_recall = 0
    epoch_f_score = 0
    
    model.eval()
    
    with torch.no_grad():
        for i, batch in enumerate(iterator):

            article_embeddings, labels, idx  = batch
            article_embeddings = article_embeddings.to(device)
            labels = labels.type(torch.float).to(device)

            outputs = model(article_embeddings)
            loss = criterion(outputs, labels)

            # calculate metrics
            preds = model.act(outputs) > 0.5

            acc, precision, recall, f1 = multi_label_scores(labels.detach().cpu(), preds.detach().cpu())
            epoch_loss += loss.item()
            epoch_acc += acc.item()
            epoch_precision += precision.item()
            epoch_recall += recall.item()
            epoch_f_score += f1.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator), \
        epoch_precision / len(iterator), epoch_recall / len(iterator), \
        epoch_f_score / len(iterator)

# %% [markdown]
# # Training

# %%
import io
import os
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from mitnewsclassify.gpt_model import GPTModel as GPTHead
from tqdm.notebook import tqdm

# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

def multi_label_scores(correct_labels, predicted_labels):

    accuracy = accuracy_score(correct_labels, predicted_labels)
    precision = precision_score(correct_labels, predicted_labels, average='weighted', zero_division=0)
    recall = recall_score(correct_labels, predicted_labels, average='weighted', zero_division=0)
    f_1_score = f1_score(correct_labels, predicted_labels, average='weighted', zero_division=0)
    
    return accuracy, precision, recall, f_1_score

def gettags(head_model, features, eval=False):
    head_model.eval()
    features = features.unsqueeze(0).to(device)
    with torch.no_grad():
        logits = head_model(features)
        multi_label_sigmoids = head_model.act(logits)

    preds = multi_label_sigmoids > 0.5
    preds = preds.detach().cpu()

    return mlb.inverse_transform(preds)

# %%
train_dataset = torch.load('gpt_embedded_train_100k.pt')
test_dataset = torch.load('gpt_embedded_test_100k.pt')

print('X_train', train_dataset.X.shape)
print('y_train', train_dataset.y.shape)

print('X_test', test_dataset.X.shape)
print('y_test', test_dataset.y.shape)
# Out:
# X_train torch.Size([100000, 768])
# y_train torch.Size([100000, 538])
# X_test torch.Size([10000, 768])
# y_test torch.Size([10000, 538])

# %%
# splitting train/validation
batch_size = 128

train_subset, valid_subset = validation_split(train_dataset, 0.1, seed)
train_loader = DataLoader(train_subset, batch_size=batch_size)
valid_loader = DataLoader(valid_subset, batch_size=batch_size)

n_training_samples = train_dataset.X.shape[0]

# %%
from mitnewsclassify2.gpt_model import GPTModel as GPTHead2

criterion = nn.BCEWithLogitsLoss()

# %%
# %%time
# hyperparams
max_epochs = 1000

patience = 10

# model
model = GPTHead2(768, 538).to(device)

optimizer = optim.Adam(model.parameters(),
                    lr = 5e-1, # default is 5e-5, our notebook had 2e-5
                  )

wandb.init(
    entity='ut-mit-news-classify',
    project="NYT Multilabeling",
)
# Magic
# wandb.watch(model)

# training
epochs_of_no_improvement = 0
best_valid_loss = float('inf')

wandb.config.early_stopping_patience = patience
wandb.config.training_samples=n_training_samples

model_file_name = f'nyt_gtp2_prevectorized_on_{n_training_samples}_samples.pt'

for epoch in range(max_epochs):

    start_time = time.time()
    
    train_loss, train_acc, train_precision, train_recall, train_f_score \
        = train(model, train_loader, optimizer, criterion)
    valid_loss, valid_acc, valid_precision, valid_recall, valid_f_score \
        = evaluate(model, valid_loader, criterion)
    
    end_time = time.time()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        print(f'New validation loss {valid_loss} is better than the best validation loss {best_valid_loss} so far.')
        best_valid_loss = valid_loss
        torch.save(model, model_file_name)
        epochs_of_no_improvement = 0
    else: 
        epochs_of_no_improvement += 1
    
    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}% | ' +
          f'Train Precision: {train_precision*100:.2f}% | Train Recall: {train_recall*100:.2f}% | ' +
          f'Train F1-score: {train_f_score*100:.2f}%')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}% | ' +
          f'Val. Precision: {valid_precision*100:.2f}% | Val. Recall: {valid_recall*100:.2f}% | ' +
          f'Val. F1-score: {valid_f_score*100:.2f}%')
    
    wandb.log({"train_loss": train_loss, 
                "train_precision": train_precision, 
                "train_f_score": train_f_score, 
                "train_acc": train_acc,
                "train_recall": train_recall,
               "valid_loss": valid_loss,
               "valid_acc": valid_acc,
               "valid_precision": valid_precision,
               "valid_recall": valid_recall,
               "valid_f_score": valid_f_score,
               "epoch": epoch+1,
                })
    # check if the training should be stopped and then stop the training
    if epochs_of_no_improvement == patience : 
        print(f'Early stopping, on epoch: {epoch+1}.')
        break
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: ut-mit-news-classify (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.30<br/>
#                 Syncing run <strong style="color:#cdcd00">wise-shadow-25</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ut-mit-news-classify/NYT%20Multilabeling" target="_blank">https://wandb.ai/ut-mit-news-classify/NYT%20Multilabeling</a><br/>
#                 Run page: <a href="https://wandb.ai/ut-mit-news-classify/NYT%20Multilabeling/runs/17atwzgx" target="_blank">https://wandb.ai/ut-mit-news-classify/NYT%20Multilabeling/runs/17atwzgx</a><br/>
#                 Run data is saved locally in <code>/home/mbaliesnyi/code/nlp-project/ut-mit-news-classify/NYT/wandb/run-20210511_202041-17atwzgx</code><br/><br/>
# New validation loss 0.02632288663070413 is better than the best validation loss inf so far.
# Epoch: 01 | Epoch Time: 0m 16s
# 	Train Loss: 0.032 | Train Acc: 3.90% | Train Precision: 7.77% | Train Recall: 4.80% | Train F1-score: 5.46%
# 	 Val. Loss: 0.026 |  Val. Acc: 4.84% | Val. Precision: 11.35% | Val. Recall: 5.18% | Val. F1-score: 6.44%
# New validation loss 0.023372430354356766 is better than the best validation loss 0.02632288663070413 so far.
# Epoch: 02 | Epoch Time: 0m 16s
# 	Train Loss: 0.025 | Train Acc: 7.87% | Train Precision: 16.27% | Train Recall: 10.44% | Train F1-score: 11.83%
# 	 Val. Loss: 0.023 |  Val. Acc: 8.77% | Val. Precision: 18.98% | Val. Recall: 10.29% | Val. F1-score: 12.35%
# Epoch: 03 | Epoch Time: 0m 16s
# 	Train Loss: 0.024 | Train Acc: 9.89% | Train Precision: 21.46% | Train Recall: 13.81% | Train F1-score: 15.67%
# 	 Val. Loss: 0.024 |  Val. Acc: 9.22% | Val. Precision: 16.41% | Val. Recall: 7.16% | Val. F1-score: 8.81%
# New validation loss 0.022612555683413638 is better than the best validation loss 0.023372430354356766 so far.
# Epoch: 04 | Epoch Time: 0m 16s
# 	Train Loss: 0.023 | Train Acc: 11.84% | Train Precision: 24.66% | Train Recall: 15.95% | Train F1-score: 18.03%
# 	 Val. Loss: 0.023 |  Val. Acc: 11.89% | Val. Precision: 20.23% | Val. Recall: 10.13% | Val. F1-score: 12.36%
# New validation loss 0.021722819632555866 is better than the best validation loss 0.022612555683413638 so far.
# Epoch: 05 | Epoch Time: 0m 16s
# 	Train Loss: 0.022 | Train Acc: 13.50% | Train Precision: 26.84% | Train Recall: 17.55% | Train F1-score: 19.81%
# 	 Val. Loss: 0.022 |  Val. Acc: 14.02% | Val. Precision: 24.89% | Val. Recall: 12.40% | Val. F1-score: 15.31%
# New validation loss 0.02105637403983104 is better than the best validation loss 0.021722819632555866 so far.
# Epoch: 06 | Epoch Time: 0m 16s
# 	Train Loss: 0.022 | Train Acc: 14.55% | Train Precision: 28.89% | Train Recall: 18.90% | Train F1-score: 21.35%
# 	 Val. Loss: 0.021 |  Val. Acc: 15.20% | Val. Precision: 27.06% | Val. Recall: 13.75% | Val. F1-score: 17.02%
# New validation loss 0.020988311052699632 is better than the best validation loss 0.02105637403983104 so far.
# Epoch: 07 | Epoch Time: 0m 16s
# 	Train Loss: 0.022 | Train Acc: 15.37% | Train Precision: 30.39% | Train Recall: 19.88% | Train F1-score: 22.49%
# 	 Val. Loss: 0.021 |  Val. Acc: 15.84% | Val. Precision: 28.57% | Val. Recall: 14.88% | Val. F1-score: 18.25%
# New validation loss 0.020412936358700826 is better than the best validation loss 0.020988311052699632 so far.
# Epoch: 08 | Epoch Time: 0m 16s
# 	Train Loss: 0.021 | Train Acc: 16.00% | Train Precision: 31.91% | Train Recall: 20.97% | Train F1-score: 23.66%
# 	 Val. Loss: 0.020 |  Val. Acc: 16.44% | Val. Precision: 30.54% | Val. Recall: 15.95% | Val. F1-score: 19.51%
# Epoch: 09 | Epoch Time: 0m 16s
# 	Train Loss: 0.021 | Train Acc: 16.17% | Train Precision: 32.47% | Train Recall: 21.30% | Train F1-score: 24.04%
# 	 Val. Loss: 0.021 |  Val. Acc: 16.48% | Val. Precision: 28.42% | Val. Recall: 13.52% | Val. F1-score: 16.65%
# Epoch: 10 | Epoch Time: 0m 16s
# 	Train Loss: 0.021 | Train Acc: 17.04% | Train Precision: 34.08% | Train Recall: 22.49% | Train F1-score: 25.36%
# 	 Val. Loss: 0.021 |  Val. Acc: 17.80% | Val. Precision: 30.45% | Val. Recall: 15.59% | Val. F1-score: 19.06%
# New validation loss 0.01974249260995207 is better than the best validation loss 0.020412936358700826 so far.
# Epoch: 11 | Epoch Time: 0m 16s
# 	Train Loss: 0.020 | Train Acc: 17.67% | Train Precision: 35.40% | Train Recall: 23.36% | Train F1-score: 26.37%
# 	 Val. Loss: 0.020 |  Val. Acc: 18.55% | Val. Precision: 34.53% | Val. Recall: 19.76% | Val. F1-score: 23.66%
# New validation loss 0.019052899525135378 is better than the best validation loss 0.01974249260995207 so far.
# Epoch: 12 | Epoch Time: 0m 16s
# 	Train Loss: 0.020 | Train Acc: 18.21% | Train Precision: 36.37% | Train Recall: 24.11% | Train F1-score: 27.21%
# 	 Val. Loss: 0.019 |  Val. Acc: 20.96% | Val. Precision: 38.38% | Val. Recall: 24.95% | Val. F1-score: 28.74%
# Epoch: 13 | Epoch Time: 0m 16s
# 	Train Loss: 0.020 | Train Acc: 18.56% | Train Precision: 36.98% | Train Recall: 24.50% | Train F1-score: 27.66%
# 	 Val. Loss: 0.019 |  Val. Acc: 18.75% | Val. Precision: 35.27% | Val. Recall: 20.48% | Val. F1-score: 24.42%
# Epoch: 14 | Epoch Time: 0m 16s
# 	Train Loss: 0.020 | Train Acc: 18.61% | Train Precision: 37.39% | Train Recall: 24.80% | Train F1-score: 27.97%
# 	 Val. Loss: 0.019 |  Val. Acc: 20.29% | Val. Precision: 36.18% | Val. Recall: 20.84% | Val. F1-score: 24.93%
# New validation loss 0.01871173594241278 is better than the best validation loss 0.019052899525135378 so far.
# Epoch: 15 | Epoch Time: 0m 16s
# 	Train Loss: 0.020 | Train Acc: 19.28% | Train Precision: 38.45% | Train Recall: 25.67% | Train F1-score: 28.92%
# 	 Val. Loss: 0.019 |  Val. Acc: 20.85% | Val. Precision: 37.58% | Val. Recall: 22.73% | Val. F1-score: 26.80%
# Epoch: 16 | Epoch Time: 0m 16s
# 	Train Loss: 0.019 | Train Acc: 19.49% | Train Precision: 38.93% | Train Recall: 25.99% | Train F1-score: 29.27%
# 	 Val. Loss: 0.019 |  Val. Acc: 19.89% | Val. Precision: 36.03% | Val. Recall: 20.67% | Val. F1-score: 24.71%
# New validation loss 0.0185724407599508 is better than the best validation loss 0.01871173594241278 so far.
# Epoch: 17 | Epoch Time: 0m 16s
# 	Train Loss: 0.019 | Train Acc: 19.61% | Train Precision: 39.14% | Train Recall: 26.26% | Train F1-score: 29.53%
# 	 Val. Loss: 0.019 |  Val. Acc: 21.42% | Val. Precision: 39.39% | Val. Recall: 22.73% | Val. F1-score: 27.28%
# New validation loss 0.018565942167858535 is better than the best validation loss 0.0185724407599508 so far.
# Epoch: 18 | Epoch Time: 0m 16s
# 	Train Loss: 0.019 | Train Acc: 20.09% | Train Precision: 40.14% | Train Recall: 26.99% | Train F1-score: 30.37%
# 	 Val. Loss: 0.019 |  Val. Acc: 22.06% | Val. Precision: 40.59% | Val. Recall: 24.33% | Val. F1-score: 28.78%
# New validation loss 0.018334420657233348 is better than the best validation loss 0.018565942167858535 so far.
# Epoch: 19 | Epoch Time: 0m 16s
# 	Train Loss: 0.019 | Train Acc: 20.26% | Train Precision: 40.37% | Train Recall: 27.35% | Train F1-score: 30.72%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.74% | Val. Precision: 41.18% | Val. Recall: 26.71% | Val. F1-score: 30.75%
# Epoch: 20 | Epoch Time: 0m 16s
# 	Train Loss: 0.019 | Train Acc: 20.27% | Train Precision: 40.65% | Train Recall: 27.42% | Train F1-score: 30.81%
# 	 Val. Loss: 0.019 |  Val. Acc: 21.53% | Val. Precision: 39.57% | Val. Recall: 22.92% | Val. F1-score: 27.39%
# Epoch: 21 | Epoch Time: 0m 16s
# 	Train Loss: 0.019 | Train Acc: 20.30% | Train Precision: 40.75% | Train Recall: 27.57% | Train F1-score: 30.92%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.56% | Val. Precision: 42.05% | Val. Recall: 25.54% | Val. F1-score: 30.15%
# Epoch: 22 | Epoch Time: 0m 16s
# 	Train Loss: 0.019 | Train Acc: 20.68% | Train Precision: 41.63% | Train Recall: 28.18% | Train F1-score: 31.65%
# 	 Val. Loss: 0.019 |  Val. Acc: 21.10% | Val. Precision: 38.19% | Val. Recall: 22.14% | Val. F1-score: 26.48%
# New validation loss 0.018283878842109365 is better than the best validation loss 0.018334420657233348 so far.
# Epoch: 23 | Epoch Time: 0m 16s
# 	Train Loss: 0.019 | Train Acc: 20.79% | Train Precision: 41.90% | Train Recall: 28.40% | Train F1-score: 31.88%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.04% | Val. Precision: 40.32% | Val. Recall: 25.51% | Val. F1-score: 29.70%
# New validation loss 0.01813118515795545 is better than the best validation loss 0.018283878842109365 so far.
# Epoch: 24 | Epoch Time: 0m 16s
# 	Train Loss: 0.019 | Train Acc: 21.01% | Train Precision: 42.37% | Train Recall: 28.83% | Train F1-score: 32.38%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.40% | Val. Precision: 41.63% | Val. Recall: 26.56% | Val. F1-score: 30.86%
# New validation loss 0.018061934817063658 is better than the best validation loss 0.01813118515795545 so far.
# Epoch: 25 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 21.29% | Train Precision: 42.85% | Train Recall: 29.31% | Train F1-score: 32.87%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.93% | Val. Precision: 42.12% | Val. Recall: 25.54% | Val. F1-score: 30.19%
# Epoch: 26 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 21.09% | Train Precision: 42.78% | Train Recall: 29.19% | Train F1-score: 32.71%
# 	 Val. Loss: 0.018 |  Val. Acc: 21.84% | Val. Precision: 40.25% | Val. Recall: 25.80% | Val. F1-score: 29.82%
# Epoch: 27 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 21.29% | Train Precision: 43.02% | Train Recall: 29.50% | Train F1-score: 33.03%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.51% | Val. Precision: 41.83% | Val. Recall: 26.13% | Val. F1-score: 30.55%
# Epoch: 28 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 21.44% | Train Precision: 43.26% | Train Recall: 29.69% | Train F1-score: 33.22%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.06% | Val. Precision: 42.70% | Val. Recall: 26.93% | Val. F1-score: 31.37%
# New validation loss 0.017950726225029065 is better than the best validation loss 0.018061934817063658 so far.
# Epoch: 29 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 21.69% | Train Precision: 43.90% | Train Recall: 30.20% | Train F1-score: 33.81%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.98% | Val. Precision: 43.31% | Val. Recall: 28.53% | Val. F1-score: 32.72%
# Epoch: 30 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 21.48% | Train Precision: 43.52% | Train Recall: 29.92% | Train F1-score: 33.43%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.97% | Val. Precision: 43.50% | Val. Recall: 27.12% | Val. F1-score: 31.73%
# Epoch: 31 | Epoch Time: 0m 16s
# 	Train Loss: 0.019 | Train Acc: 20.31% | Train Precision: 41.83% | Train Recall: 28.42% | Train F1-score: 31.82%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.92% | Val. Precision: 41.92% | Val. Recall: 26.53% | Val. F1-score: 30.90%
# New validation loss 0.017802743759902217 is better than the best validation loss 0.017950726225029065 so far.
# Epoch: 32 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 21.55% | Train Precision: 43.92% | Train Recall: 30.12% | Train F1-score: 33.73%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.70% | Val. Precision: 44.09% | Val. Recall: 28.33% | Val. F1-score: 32.79%
# Epoch: 33 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 22.06% | Train Precision: 44.91% | Train Recall: 30.96% | Train F1-score: 34.69%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.67% | Val. Precision: 42.18% | Val. Recall: 25.50% | Val. F1-score: 30.11%
# Epoch: 34 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 21.81% | Train Precision: 44.43% | Train Recall: 30.78% | Train F1-score: 34.37%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.45% | Val. Precision: 41.23% | Val. Recall: 27.59% | Val. F1-score: 31.49%
# Epoch: 35 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 22.05% | Train Precision: 45.07% | Train Recall: 31.25% | Train F1-score: 34.92%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.98% | Val. Precision: 43.60% | Val. Recall: 28.75% | Val. F1-score: 32.93%
# Epoch: 36 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 22.07% | Train Precision: 45.34% | Train Recall: 31.47% | Train F1-score: 35.14%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.60% | Val. Precision: 43.79% | Val. Recall: 28.63% | Val. F1-score: 32.92%
# Epoch: 37 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 22.02% | Train Precision: 45.19% | Train Recall: 31.36% | Train F1-score: 35.03%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.93% | Val. Precision: 43.81% | Val. Recall: 26.48% | Val. F1-score: 31.28%
# Epoch: 38 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 22.19% | Train Precision: 45.48% | Train Recall: 31.65% | Train F1-score: 35.30%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.13% | Val. Precision: 43.11% | Val. Recall: 26.21% | Val. F1-score: 30.87%
# Epoch: 39 | Epoch Time: 0m 16s
# 	Train Loss: 0.018 | Train Acc: 22.19% | Train Precision: 45.90% | Train Recall: 31.90% | Train F1-score: 35.59%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.01% | Val. Precision: 44.03% | Val. Recall: 27.92% | Val. F1-score: 32.49%
# Epoch: 40 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.30% | Train Precision: 46.10% | Train Recall: 32.06% | Train F1-score: 35.82%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.23% | Val. Precision: 42.44% | Val. Recall: 24.37% | Val. F1-score: 29.23%
# Epoch: 41 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.34% | Train Precision: 46.12% | Train Recall: 32.07% | Train F1-score: 35.81%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.36% | Val. Precision: 43.04% | Val. Recall: 25.60% | Val. F1-score: 30.41%
# New validation loss 0.017774417642739754 is better than the best validation loss 0.017802743759902217 so far.
# Epoch: 42 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.49% | Train Precision: 46.45% | Train Recall: 32.40% | Train F1-score: 36.15%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.92% | Val. Precision: 45.29% | Val. Recall: 29.69% | Val. F1-score: 34.16%
# Epoch: 43 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.49% | Train Precision: 46.58% | Train Recall: 32.41% | Train F1-score: 36.16%
# 	 Val. Loss: 0.018 |  Val. Acc: 24.02% | Val. Precision: 44.44% | Val. Recall: 32.02% | Val. F1-score: 35.48%
# Epoch: 44 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.71% | Train Precision: 46.86% | Train Recall: 32.90% | Train F1-score: 36.65%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.76% | Val. Precision: 44.41% | Val. Recall: 29.37% | Val. F1-score: 33.63%
# Epoch: 45 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.59% | Train Precision: 46.71% | Train Recall: 32.76% | Train F1-score: 36.46%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.61% | Val. Precision: 44.43% | Val. Recall: 27.54% | Val. F1-score: 32.10%
# Epoch: 46 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.70% | Train Precision: 46.99% | Train Recall: 32.98% | Train F1-score: 36.72%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.45% | Val. Precision: 44.74% | Val. Recall: 29.70% | Val. F1-score: 34.00%
# Epoch: 47 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.75% | Train Precision: 47.26% | Train Recall: 33.17% | Train F1-score: 36.94%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.56% | Val. Precision: 44.35% | Val. Recall: 28.59% | Val. F1-score: 33.02%
# Epoch: 48 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.79% | Train Precision: 47.42% | Train Recall: 33.35% | Train F1-score: 37.12%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.24% | Val. Precision: 43.77% | Val. Recall: 26.93% | Val. F1-score: 31.69%
# Epoch: 49 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.73% | Train Precision: 47.40% | Train Recall: 33.39% | Train F1-score: 37.13%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.82% | Val. Precision: 44.84% | Val. Recall: 29.38% | Val. F1-score: 33.83%
# Epoch: 50 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.96% | Train Precision: 47.65% | Train Recall: 33.61% | Train F1-score: 37.38%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.79% | Val. Precision: 45.34% | Val. Recall: 30.03% | Val. F1-score: 34.35%
# Epoch: 51 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.69% | Train Precision: 47.50% | Train Recall: 33.42% | Train F1-score: 37.17%
# 	 Val. Loss: 0.018 |  Val. Acc: 22.42% | Val. Precision: 41.83% | Val. Recall: 30.32% | Val. F1-score: 33.44%
# New validation loss 0.017590175925082045 is better than the best validation loss 0.017774417642739754 so far.
# Epoch: 52 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.95% | Train Precision: 47.61% | Train Recall: 33.65% | Train F1-score: 37.42%
# 	 Val. Loss: 0.018 |  Val. Acc: 24.44% | Val. Precision: 45.96% | Val. Recall: 31.54% | Val. F1-score: 35.60%
# Epoch: 53 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 23.16% | Train Precision: 48.18% | Train Recall: 34.04% | Train F1-score: 37.87%
# 	 Val. Loss: 0.018 |  Val. Acc: 24.22% | Val. Precision: 45.41% | Val. Recall: 30.58% | Val. F1-score: 34.82%
# Epoch: 54 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 22.93% | Train Precision: 47.98% | Train Recall: 33.88% | Train F1-score: 37.66%
# 	 Val. Loss: 0.018 |  Val. Acc: 24.14% | Val. Precision: 45.64% | Val. Recall: 30.59% | Val. F1-score: 34.83%
# Epoch: 55 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 23.06% | Train Precision: 48.16% | Train Recall: 34.11% | Train F1-score: 37.87%
# 	 Val. Loss: 0.018 |  Val. Acc: 24.02% | Val. Precision: 45.79% | Val. Recall: 29.30% | Val. F1-score: 33.85%
# Epoch: 56 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 23.25% | Train Precision: 48.56% | Train Recall: 34.50% | Train F1-score: 38.28%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.67% | Val. Precision: 45.29% | Val. Recall: 29.66% | Val. F1-score: 34.11%
# Epoch: 57 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 23.34% | Train Precision: 48.55% | Train Recall: 34.53% | Train F1-score: 38.31%
# 	 Val. Loss: 0.018 |  Val. Acc: 24.19% | Val. Precision: 45.96% | Val. Recall: 32.03% | Val. F1-score: 36.08%
# Epoch: 58 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 23.22% | Train Precision: 48.53% | Train Recall: 34.44% | Train F1-score: 38.18%
# 	 Val. Loss: 0.018 |  Val. Acc: 24.04% | Val. Precision: 45.21% | Val. Recall: 30.62% | Val. F1-score: 34.79%
# Epoch: 59 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 23.21% | Train Precision: 48.43% | Train Recall: 34.36% | Train F1-score: 38.14%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.49% | Val. Precision: 44.23% | Val. Recall: 29.31% | Val. F1-score: 33.52%
# Epoch: 60 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 23.25% | Train Precision: 48.82% | Train Recall: 34.79% | Train F1-score: 38.58%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.68% | Val. Precision: 44.66% | Val. Recall: 28.46% | Val. F1-score: 33.07%
# Epoch: 61 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 23.29% | Train Precision: 49.00% | Train Recall: 34.89% | Train F1-score: 38.69%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.58% | Val. Precision: 44.36% | Val. Recall: 28.75% | Val. F1-score: 33.14%
# Epoch: 62 | Epoch Time: 0m 16s
# 	Train Loss: 0.017 | Train Acc: 23.38% | Train Precision: 49.12% | Train Recall: 34.99% | Train F1-score: 38.82%
# 	 Val. Loss: 0.018 |  Val. Acc: 23.27% | Val. Precision: 44.10% | Val. Recall: 27.83% | Val. F1-score: 32.43%
# Early stopping, on epoch: 62.
# CPU times: user 1h 18min 15s, sys: 3.79 s, total: 1h 18min 19s
# Wall time: 17min 9s

# %%
idx = 15
print('predicted', gettags(model, train_dataset.X[idx]))
print('gold:', mlb.inverse_transform(train_dataset.y[idx].unsqueeze(0)))
# Out:
# predicted [('politics and government',)]
# gold: [('armament, defense and military forces',)]

# %%
test_model = torch.load('nyt_gtp2_prevectorized_on_100000_samples.pt')
test_loader = DataLoader(test_dataset, batch_size=128)

start_time = time.time()
test_loss, test_acc, test_precision, test_recall, test_f_score \
    = evaluate(test_model, test_loader, criterion)
end_time = time.time()
epoch_mins, epoch_secs = epoch_time(start_time, end_time)

print(f'Epoch: test | Epoch Time: {epoch_mins}m {epoch_secs}s')
print(f'\tTest Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}% | ' +
      f'Test Precision: {test_precision*100:.2f}% | Test Recall: {test_recall*100:.2f}% | ' +
      f'Test F1-score: {test_f_score*100:.2f}%')
# Out:
# Epoch: test | Epoch Time: 0m 1s
# 	Test Loss: 0.018 | Test Acc: 23.51% | Test Precision: 45.93% | Test Recall: 31.37% | Test F1-score: 35.50%
